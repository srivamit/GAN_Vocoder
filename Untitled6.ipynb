# %% [markdown]
# <a href="https://colab.research.google.com/github/RishabhDimri/GAN_Vocoder/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install webdataset
# !pip install jiwer
# !pip install datasets
# !pip install torch
# !pip install pyannote.audio
# !pip install googletrans==4.0.0-rc1
# !pip install youtokentome
# !pip install hydra-core
# !pip install omegaconf
# !pip install pytorch-lightning
# !pip install wandb
# !pip install nemo_text_processing
# !pip install nemo
# !pip install nemo-toolkit
# !pip install pygame
# !pip install lhotse
# !pip install gTTS pydub playsound

# %%
from pydub import AudioSegment

def mp3_to_wav(mp3_file, wav_file):
    # Load the MP3 file
    audio = AudioSegment.from_mp3(mp3_file)

    # Export the audio to WAV format
    audio.export(wav_file, format="wav")

# Replace 'input.mp3' and 'output.wav' with your input and output file paths
mp3_to_wav("/content/start1 (1).mp3", "output.wav")

# %%
import soundfile as sf
from nemo.collections.tts.models import FastPitchModel, HifiGanModel
import speech_recognition as sr

# Load FastPitch
spec_generator = FastPitchModel.from_pretrained("nvidia/tts_en_fastpitch")

# Load vocoder
model = HifiGanModel.from_pretrained(model_name="nvidia/tts_hifigan")
# Out:
#  NeMo-text-processing :: INFO     :: Creating ClassifyFst grammars.
# INFO:NeMo-text-processing:Creating ClassifyFst grammars.
# [NeMo W 2024-03-16 05:27:01 en_us_arpabet:66] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2024-03-16 05:27:01 modelPT:165] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
# ...

# %%
import speech_recognition as sr

# Initialize the recognizer
recognizer = sr.Recognizer()

# Load the audio file
audio_file = '/content/output.wav'

# Use the recognizer to open the audio file
with sr.AudioFile(audio_file) as source:
    # Record the audio data from the file
    audio_data = recognizer.record(source)

    try:
        # Use the recognizer to convert the audio to text
        text = recognizer.recognize_google(audio_data)
        print("Text: ", text)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand the audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))
# Out:
# Text:  hello world our team is Tech nerds and this is our project audio IDK today we will win IGS

# %%
from googletrans import Translator
import pandas as pd
import re
import os
from gtts import gTTS
from IPython.display import Audio

# Function to speak the translated text
def speak_text(text, lang):
    tts = gTTS(text=text, lang=lang)
    tts.save("greeting.mp3")
    return Audio("greeting.mp3", autoplay=True)

# Load your dataset containing acronyms and sentences
dataset_path = "slang.csv"  # Update this with your dataset path
acronym_data = pd.read_csv(dataset_path)

# Function to build a dictionary mapping acronyms and slangs to sentences
def build_dictionary(data):
    acronym_dict = {}
    for index, row in data.iterrows():
        term = row['acronym'].lower()
        sentence = row['expansion']
        if term not in acronym_dict:
            acronym_dict[term] = sentence
        acronym_dict[sentence.lower()] = sentence  # Add sentence itself for slang
    return acronym_dict

# Build the dictionary
dictionary = build_dictionary(acronym_data)

# Function to resolve acronyms and slangs in a sentence
def resolve_sentence(sentence):
    # Tokenize the sentence
    tokens = re.findall(r'\b\w+\b', sentence)
    result = []
    for token in tokens:
        # Check if token is in dictionary
        if token.lower() in dictionary:
            result.append(dictionary[token.lower()])
        else:
            result.append(token)
    return ' '.join(result)

# Function to translate a sentence to a target language
def translate_sentence(sentence, target_language='en'):
    translator = Translator()
    translation = translator.translate(sentence, dest=target_language)
    return translation.text

# Main loop for user interaction
# while True:
#     user_input = input("type 'exit' to quit): ")
#     if user_input.lower() == 'exit':
#         print("Exiting...")
#         break
#     else:
resolved_sentence = resolve_sentence(text)
print("Resolved Sentence:", resolved_sentence)
print("Translation Options:")
print("1. French (fr)")
print("2. Spanish (es)")
print("3. German (de)")
print("4. Italian (it)")
print("5. Russian (ru)")
print("6. Chinese (zh-CN)")
print("7. Hindi (hi)")
print("8. English (en)")
print("9. Japanese (ja)")
target_language = input("Enter the number of the desired language option: ")
if target_language.lower() == 'exit':
    print("Exiting...")
elif target_language.isdigit() and 1 <= int(target_language) <= 9:
    languages = ['fr', 'es', 'de', 'it', 'ru', 'zh-CN', 'hi', 'en', 'ja']
    translated_sentence = translate_sentence(resolved_sentence, target_language=languages[int(target_language)-1])
    print("Translated Result:", translated_sentence)
    speak_text(translated_sentence, lang=languages[int(target_language)-1])
else:
    print("Invalid option. Please enter a number from 1 to 9.")
# Out:
# Resolved Sentence: hello world our team is Tech nerds and this is our project audio i do not know today whatever will win i guess so
# Translation Options:
# 1. French (fr)
# 2. Spanish (es)
# 3. German (de)
# 4. Italian (it)
# 5. Russian (ru)
# 6. Chinese (zh-CN)
# 7. Hindi (hi)
# 8. English (en)
# 9. Japanese (ja)
# Enter the number of the desired language option: 7
# Translated Result: हैलो वर्ल्ड हमारी टीम टेक नर्ड्स है और यह हमारा प्रोजेक्ट ऑडियो है, मुझे नहीं पता कि आज जो कुछ भी मुझे लगता है कि मुझे ऐसा लगता है
